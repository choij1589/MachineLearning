# %%
import gym
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.distributions import Categorical

# %%
# Hyperparameters
LR = 0.0002
GAMMA = 0.98
N_ROLLOUT = 10      # update networks for every 10 transitions

# %%
class ActorCritic(nn.Module):
    def __init__(self):
        super(ActorCritic, self).__init__()
        self.data = []
        
        self.fc1 = nn.Linear(4, 256)
        self.fc_policy = nn.Linear(256, 2)
        self.fc_value = nn.Linear(256, 1)
        self.optimizer = optim.Adam(self.parameters(), lr=LR)
        
    def policy(self, x, softmax_dim=0):
        x = F.relu(self.fc1(x))
        x = self.fc_policy(x)
        prob = F.softmax(x, dim=softmax_dim)
        
        return prob
    
    def value(self, x):
        x = F.relu(self.fc1(x))
        value = self.fc_value(x)
        
        return value

    def put_data(self, transition):
        self.data.append(transition)
        
    def make_batch(self):
        states, actions, rewards, next_states, done_masks = [], [], [], [], []
        for transition in self.data:
            state, action, reward, next_state, done_mask = transition
            states.append(state)
            actions.append([action])
            rewards.append([reward/100.])
            next_states.append(next_state)
            done_masks.append([0. if done_mask else 1.])

        state_batch = torch.tensor(states, dtype=torch.float)
        action_batch = torch.tensor(actions)
        reward_batch = torch.tensor(rewards, dtype=torch.float)
        next_state_batch = torch.tensor(next_states, dtype=torch.float)
        done_mask_batch = torch.tensor(done_masks, dtype=torch.float)
        self.data = []
        return (state_batch, action_batch, reward_batch, next_state_batch, done_mask_batch)

    def train_net(self):
        state, action, reward, next_state, done_mask = self.make_batch()
        td_target = reward + GAMMA*self.value(next_state)*done_mask         # done_mask for episodic scenario
        delta = td_target - self.value(state)
        
        policy = self.policy(state, softmax_dim=1)
        policy_a = policy.gather(1, action)
        loss = -torch.log(policy_a) * delta.detach() + F.smooth_l1_loss(self.value(state), td_target.detach())
        
        self.optimizer.zero_grad()
        loss.mean().backward()
        self.optimizer.step()

# %%
env = gym.make('CartPole-v1')
model = ActorCritic()
score = 0.

for n_epi in range(10000):
    done = False
    state = env.reset()
    
    while not done:
        for transition in range(N_ROLLOUT):
            prob = model.policy(torch.from_numpy(state).float())
            m = Categorical(prob)
            action = m.sample().item()
            next_state, reward, done, info = env.step(action)
            model.put_data((state, action, reward, next_state, done))
            
            state = next_state
            score += reward
            
            if done:
                break
            
        model.train_net()
    
    if n_epi%20==0 and n_epi != 0:
        print(f"[EPISODE {n_epi}] avg score: {score/n_epi}")
        score = 0.

env.close()
# Out:
# [EPISODE 20] avg score: 21.05
# [EPISODE 40] avg score: 8.95
# [EPISODE 60] avg score: 5.466666666666667
# [EPISODE 80] avg score: 5.2625
# [EPISODE 100] avg score: 3.52
# [EPISODE 120] avg score: 3.716666666666667
# [EPISODE 140] avg score: 3.3714285714285714
# [EPISODE 160] avg score: 3.90625
# [EPISODE 180] avg score: 3.588888888888889
# [EPISODE 200] avg score: 3.095
# [EPISODE 220] avg score: 3.2590909090909093
# [EPISODE 240] avg score: 3.370833333333333
# [EPISODE 260] avg score: 2.3076923076923075
# [EPISODE 280] avg score: 1.9928571428571429
# [EPISODE 300] avg score: 1.8033333333333332
# [EPISODE 320] avg score: 2.0875
# [EPISODE 340] avg score: 1.9676470588235293
# [EPISODE 360] avg score: 1.625
# [EPISODE 380] avg score: 1.7552631578947369
# [EPISODE 400] avg score: 1.7625
# [EPISODE 420] avg score: 1.3976190476190475
# [EPISODE 440] avg score: 1.3386363636363636
# [EPISODE 460] avg score: 1.1695652173913043
# [EPISODE 480] avg score: 1.81875
# [EPISODE 500] avg score: 2.43
# [EPISODE 520] avg score: 2.498076923076923
# [EPISODE 540] avg score: 2.1777777777777776
# [EPISODE 560] avg score: 2.5607142857142855
# [EPISODE 580] avg score: 2.213793103448276
# [EPISODE 600] avg score: 2.065
# [EPISODE 620] avg score: 1.5290322580645161
# [EPISODE 640] avg score: 1.603125
# [EPISODE 660] avg score: 1.3
# [EPISODE 680] avg score: 0.7529411764705882
# [EPISODE 700] avg score: 0.5871428571428572
# [EPISODE 720] avg score: 0.5319444444444444
# [EPISODE 740] avg score: 0.4554054054054054
# [EPISODE 760] avg score: 0.34342105263157896
# [EPISODE 780] avg score: 0.358974358974359
# [EPISODE 800] avg score: 0.4325
# [EPISODE 820] avg score: 0.4768292682926829
# [EPISODE 840] avg score: 0.46785714285714286
# [EPISODE 860] avg score: 0.577906976744186
# [EPISODE 880] avg score: 0.4909090909090909
# [EPISODE 900] avg score: 0.4722222222222222
# [EPISODE 920] avg score: 0.5293478260869565
# [EPISODE 940] avg score: 0.7542553191489362
# [EPISODE 960] avg score: 1.25625
# [EPISODE 980] avg score: 0.6979591836734694
# [EPISODE 1000] avg score: 0.589
# [EPISODE 1020] avg score: 0.6
# [EPISODE 1040] avg score: 0.510576923076923
# [EPISODE 1060] avg score: 0.4367924528301887
# [EPISODE 1080] avg score: 0.47685185185185186
# [EPISODE 1100] avg score: 0.36363636363636365
# [EPISODE 1120] avg score: 0.31339285714285714
# [EPISODE 1140] avg score: 0.2964912280701754
# [EPISODE 1160] avg score: 0.2637931034482759
# [EPISODE 1180] avg score: 0.26610169491525426
# [EPISODE 1200] avg score: 0.245
# [EPISODE 1220] avg score: 0.22049180327868853
# [EPISODE 1240] avg score: 0.19919354838709677
# [EPISODE 1260] avg score: 0.20793650793650795
# [EPISODE 1280] avg score: 0.21875
# [EPISODE 1300] avg score: 0.24384615384615385
# [EPISODE 1320] avg score: 0.21363636363636362
# [EPISODE 1340] avg score: 0.23955223880597015
# [EPISODE 1360] avg score: 0.23602941176470588
# [EPISODE 1380] avg score: 0.27246376811594203
# [EPISODE 1400] avg score: 0.27071428571428574
# [EPISODE 1420] avg score: 0.2774647887323944
# [EPISODE 1440] avg score: 0.3451388888888889
# [EPISODE 1460] avg score: 0.34315068493150686
# [EPISODE 1480] avg score: 0.3236486486486487
# [EPISODE 1500] avg score: 0.42733333333333334
# [EPISODE 1520] avg score: 0.3868421052631579
# [EPISODE 1540] avg score: 0.7116883116883117
# [EPISODE 1560] avg score: 0.8134615384615385
# [EPISODE 1580] avg score: 0.5670886075949367
# [EPISODE 1600] avg score: 0.679375
# [EPISODE 1620] avg score: 0.40370370370370373
# [EPISODE 1640] avg score: 0.36585365853658536
# [EPISODE 1660] avg score: 0.6066265060240964
# [EPISODE 1680] avg score: 0.6142857142857143
# [EPISODE 1700] avg score: 0.49117647058823527
# [EPISODE 1720] avg score: 0.47790697674418603
# [EPISODE 1740] avg score: 0.6436781609195402
# [EPISODE 1760] avg score: 0.44772727272727275
# [EPISODE 1780] avg score: 0.8634831460674157
# [EPISODE 1800] avg score: 0.5044444444444445
# [EPISODE 1820] avg score: 0.4087912087912088
# [EPISODE 1840] avg score: 0.6201086956521739
# [EPISODE 1860] avg score: 0.5645161290322581
# [EPISODE 1880] avg score: 0.5074468085106383
# [EPISODE 1900] avg score: 0.35368421052631577
# [EPISODE 1920] avg score: 0.48020833333333335
# [EPISODE 1940] avg score: 0.5520618556701031
# [EPISODE 1960] avg score: 0.5556122448979591
# [EPISODE 1980] avg score: 0.4782828282828283
# [EPISODE 2000] avg score: 0.4045
# [EPISODE 2020] avg score: 0.21287128712871287
# [EPISODE 2040] avg score: 0.18970588235294117
# [EPISODE 2060] avg score: 0.26019417475728157
# [EPISODE 2080] avg score: 0.19663461538461538
# [EPISODE 2100] avg score: 0.4147619047619048
# [EPISODE 2120] avg score: 0.469811320754717
# [EPISODE 2140] avg score: 0.42570093457943925
# [EPISODE 2160] avg score: 0.49074074074074076
# [EPISODE 2180] avg score: 0.45458715596330274
# [EPISODE 2200] avg score: 0.36272727272727273
# [EPISODE 2220] avg score: 0.2774774774774775
# [EPISODE 2240] avg score: 0.31785714285714284
# [EPISODE 2260] avg score: 0.5026548672566372
# [EPISODE 2280] avg score: 0.3942982456140351
# [EPISODE 2300] avg score: 0.4656521739130435
# [EPISODE 2320] avg score: 0.453448275862069
# [EPISODE 2340] avg score: 0.5273504273504274
# [EPISODE 2360] avg score: 0.6444915254237288
# [EPISODE 2380] avg score: 0.5252100840336135
# [EPISODE 2400] avg score: 0.5670833333333334
# [EPISODE 2420] avg score: 0.3851239669421488
# [EPISODE 2440] avg score: 0.28647540983606556
# [EPISODE 2460] avg score: 0.526829268292683
# [EPISODE 2480] avg score: 0.4504032258064516
# [EPISODE 2500] avg score: 0.56
# [EPISODE 2520] avg score: 0.5126984126984127
# [EPISODE 2540] avg score: 0.511023622047244
# [EPISODE 2560] avg score: 0.519140625
# [EPISODE 2580] avg score: 0.5065891472868217
# [EPISODE 2600] avg score: 0.4207692307692308
# [EPISODE 2620] avg score: 0.24236641221374045
# [EPISODE 2640] avg score: 0.3007575757575758
# [EPISODE 2660] avg score: 0.3172932330827068
# [EPISODE 2680] avg score: 0.45149253731343286
# [EPISODE 2700] avg score: 0.3937037037037037
# [EPISODE 2720] avg score: 0.29705882352941176
# [EPISODE 2740] avg score: 0.23102189781021898
# [EPISODE 2760] avg score: 0.36231884057971014
# [EPISODE 2780] avg score: 0.4287769784172662
# [EPISODE 2800] avg score: 0.4446428571428571
# [EPISODE 2820] avg score: 0.4521276595744681
# [EPISODE 2840] avg score: 0.4299295774647887
# [EPISODE 2860] avg score: 0.37727272727272726
# [EPISODE 2880] avg score: 0.4253472222222222
# [EPISODE 2900] avg score: 0.3603448275862069
# [EPISODE 2920] avg score: 0.5390410958904109
# [EPISODE 2940] avg score: 0.26666666666666666
# [EPISODE 2960] avg score: 0.35574324324324325
# [EPISODE 2980] avg score: 0.19630872483221476
# [EPISODE 3000] avg score: 0.19366666666666665
# [EPISODE 3020] avg score: 0.19536423841059603
# [EPISODE 3040] avg score: 0.18421052631578946
# [EPISODE 3060] avg score: 0.19901960784313724
# [EPISODE 3080] avg score: 0.3899350649350649
# [EPISODE 3100] avg score: 0.4525806451612903
# [EPISODE 3120] avg score: 0.48365384615384616
# [EPISODE 3140] avg score: 0.28535031847133757
# [EPISODE 3160] avg score: 0.17531645569620252
# [EPISODE 3180] avg score: 0.19056603773584907
# [EPISODE 3200] avg score: 0.148125
# [EPISODE 3220] avg score: 0.16925465838509315
# [EPISODE 3240] avg score: 0.25123456790123455
# [EPISODE 3260] avg score: 0.2647239263803681
# [EPISODE 3280] avg score: 0.3003048780487805
# [EPISODE 3300] avg score: 0.36787878787878786
# [EPISODE 3320] avg score: 0.28704819277108434
# [EPISODE 3340] avg score: 0.19041916167664671
# [EPISODE 3360] avg score: 0.34523809523809523
# [EPISODE 3380] avg score: 0.4254437869822485
# [EPISODE 3400] avg score: 0.46558823529411764
# [EPISODE 3420] avg score: 0.33976608187134505
# [EPISODE 3440] avg score: 0.3520348837209302
# [EPISODE 3460] avg score: 0.32312138728323697
# [EPISODE 3480] avg score: 0.3485632183908046
# [EPISODE 3500] avg score: 0.18342857142857144
# [EPISODE 3520] avg score: 0.35
# [EPISODE 3540] avg score: 0.3977401129943503
# [EPISODE 3560] avg score: 0.37275280898876406
# [EPISODE 3580] avg score: 0.23910614525139665
# [EPISODE 3600] avg score: 0.2561111111111111
# [EPISODE 3620] avg score: 0.10414364640883977
# [EPISODE 3640] avg score: 0.08736263736263736
# [EPISODE 3660] avg score: 0.06612021857923497
# [EPISODE 3680] avg score: 0.06141304347826087
# [EPISODE 3700] avg score: 0.05891891891891892
# [EPISODE 3720] avg score: 0.06559139784946237
# [EPISODE 3740] avg score: 0.07245989304812835
# [EPISODE 3760] avg score: 0.0800531914893617
# [EPISODE 3780] avg score: 0.09047619047619047
# [EPISODE 3800] avg score: 0.09447368421052632
# [EPISODE 3820] avg score: 0.1
# [EPISODE 3840] avg score: 0.08932291666666667
# [EPISODE 3860] avg score: 0.08160621761658031
# [EPISODE 3880] avg score: 0.08943298969072165
# [EPISODE 3900] avg score: 0.10461538461538461
# [EPISODE 3920] avg score: 0.09591836734693877
# [EPISODE 3940] avg score: 0.09974619289340102
# [EPISODE 3960] avg score: 0.09015151515151515
# [EPISODE 3980] avg score: 0.08366834170854272
# [EPISODE 4000] avg score: 0.0965
# [EPISODE 4020] avg score: 0.0927860696517413
# [EPISODE 4040] avg score: 0.09851485148514852
# [EPISODE 4060] avg score: 0.10640394088669951
# [EPISODE 4080] avg score: 0.10122549019607843
# [EPISODE 4100] avg score: 0.10341463414634146
# [EPISODE 4120] avg score: 0.10024271844660194
# [EPISODE 4140] avg score: 0.08260869565217391
# [EPISODE 4160] avg score: 0.14639423076923078
# [EPISODE 4180] avg score: 0.18971291866028708
# [EPISODE 4200] avg score: 0.3461904761904762
# [EPISODE 4220] avg score: 0.2490521327014218
# [EPISODE 4240] avg score: 0.25471698113207547
# [EPISODE 4260] avg score: 0.2147887323943662
# [EPISODE 4280] avg score: 0.1455607476635514
# [EPISODE 4300] avg score: 0.11395348837209303
# [EPISODE 4320] avg score: 0.12430555555555556
# [EPISODE 4340] avg score: 0.10299539170506912
# [EPISODE 4360] avg score: 0.12660550458715597
# [EPISODE 4380] avg score: 0.12168949771689498
# [EPISODE 4400] avg score: 0.12
# [EPISODE 4420] avg score: 0.14027149321266968
# [EPISODE 4440] avg score: 0.2051801801801802
# [EPISODE 4460] avg score: 0.27623318385650225
# [EPISODE 4480] avg score: 0.2671875
# [EPISODE 4500] avg score: 0.15044444444444444
# [EPISODE 4520] avg score: 0.11548672566371682
# [EPISODE 4540] avg score: 0.07841409691629955
# [EPISODE 4560] avg score: 0.06096491228070176
# [EPISODE 4580] avg score: 0.062445414847161575
# [EPISODE 4600] avg score: 0.06956521739130435
# [EPISODE 4620] avg score: 0.06558441558441558
# [EPISODE 4640] avg score: 0.07349137931034483
# [EPISODE 4660] avg score: 0.09484978540772532
# [EPISODE 4680] avg score: 0.09358974358974359
# [EPISODE 4700] avg score: 0.07510638297872341
# [EPISODE 4720] avg score: 0.07415254237288135
# [EPISODE 4740] avg score: 0.07573839662447257
# [EPISODE 4760] avg score: 0.08340336134453781
# [EPISODE 4780] avg score: 0.07719665271966528
# [EPISODE 4800] avg score: 0.07958333333333334
# [EPISODE 4820] avg score: 0.08278008298755186
# [EPISODE 4840] avg score: 0.0768595041322314
# [EPISODE 4860] avg score: 0.08497942386831275
# [EPISODE 4880] avg score: 0.0889344262295082
# [EPISODE 4900] avg score: 0.0789795918367347
# [EPISODE 4920] avg score: 0.10284552845528455
# [EPISODE 4940] avg score: 0.15465587044534412
# [EPISODE 4960] avg score: 0.23044354838709677
# [EPISODE 4980] avg score: 0.09959839357429719
# [EPISODE 5000] avg score: 0.118
# [EPISODE 5020] avg score: 0.13565737051792828
# [EPISODE 5040] avg score: 0.09603174603174604
# [EPISODE 5060] avg score: 0.06739130434782609
# [EPISODE 5080] avg score: 0.065748031496063
# [EPISODE 5100] avg score: 0.0603921568627451
# [EPISODE 5120] avg score: 0.059765625
# [EPISODE 5140] avg score: 0.06770428015564202
# [EPISODE 5160] avg score: 0.07461240310077519
# [EPISODE 5180] avg score: 0.07895752895752896
# [EPISODE 5200] avg score: 0.08692307692307692
# [EPISODE 5220] avg score: 0.0743295019157088
# [EPISODE 5240] avg score: 0.06793893129770992
# [EPISODE 5260] avg score: 0.06482889733840304
# [EPISODE 5280] avg score: 0.07121212121212121
# [EPISODE 5300] avg score: 0.09226415094339623
# [EPISODE 5320] avg score: 0.08515037593984963
# [EPISODE 5340] avg score: 0.06741573033707865
# [EPISODE 5360] avg score: 0.07126865671641791
# [EPISODE 5380] avg score: 0.09962825278810408
# [EPISODE 5400] avg score: 0.10444444444444445
# [EPISODE 5420] avg score: 0.13136531365313653
# [EPISODE 5440] avg score: 0.09301470588235294
# [EPISODE 5460] avg score: 0.10457875457875458
# [EPISODE 5480] avg score: 0.12189781021897811
# [EPISODE 5500] avg score: 0.1421818181818182
# [EPISODE 5520] avg score: 0.1322463768115942
# [EPISODE 5540] avg score: 0.13068592057761733
# [EPISODE 5560] avg score: 0.20467625899280575
# [EPISODE 5580] avg score: 0.22473118279569892
# [EPISODE 5600] avg score: 0.22285714285714286
# [EPISODE 5620] avg score: 0.2318505338078292
# [EPISODE 5640] avg score: 0.11241134751773049
# [EPISODE 5660] avg score: 0.10600706713780919
# [EPISODE 5680] avg score: 0.10070422535211268
# [EPISODE 5700] avg score: 0.14298245614035088
# [EPISODE 5720] avg score: 0.10122377622377622
# [EPISODE 5740] avg score: 0.12630662020905922
# [EPISODE 5760] avg score: 0.23559027777777777
# [EPISODE 5780] avg score: 0.14982698961937715
# [EPISODE 5800] avg score: 0.20706896551724138
# [EPISODE 5820] avg score: 0.2063573883161512
# [EPISODE 5840] avg score: 0.1881849315068493
# [EPISODE 5860] avg score: 0.20204778156996586
# [EPISODE 5880] avg score: 0.07772108843537415
# [EPISODE 5900] avg score: 0.08932203389830508
# [EPISODE 5920] avg score: 0.09408783783783783
# [EPISODE 5940] avg score: 0.10117845117845117
# [EPISODE 5960] avg score: 0.09228187919463088
# [EPISODE 5980] avg score: 0.12658862876254182
# [EPISODE 6000] avg score: 0.11016666666666666
# [EPISODE 6020] avg score: 0.07923588039867109
# [EPISODE 6040] avg score: 0.08245033112582781
# [EPISODE 6060] avg score: 0.06897689768976897
# [EPISODE 6080] avg score: 0.061677631578947366
# [EPISODE 6100] avg score: 0.054098360655737705
# [EPISODE 6120] avg score: 0.05392156862745098
# [EPISODE 6140] avg score: 0.050814332247557006
# [EPISODE 6160] avg score: 0.05892857142857143
# [EPISODE 6180] avg score: 0.05598705501618123
# [EPISODE 6200] avg score: 0.052258064516129035
# [EPISODE 6220] avg score: 0.05128617363344051
# [EPISODE 6240] avg score: 0.05368589743589743
# [EPISODE 6260] avg score: 0.04824281150159744
# [EPISODE 6280] avg score: 0.04331210191082802
# [EPISODE 6300] avg score: 0.0392063492063492
# [EPISODE 6320] avg score: 0.04066455696202532
# [EPISODE 6340] avg score: 0.038012618296529965
# [EPISODE 6360] avg score: 0.040880503144654086
# [EPISODE 6380] avg score: 0.039968652037617555
# [EPISODE 6400] avg score: 0.03671875
# [EPISODE 6420] avg score: 0.03847352024922118
# [EPISODE 6440] avg score: 0.03804347826086957
# [EPISODE 6460] avg score: 0.03885448916408669
# [EPISODE 6480] avg score: 0.0404320987654321
# [EPISODE 6500] avg score: 0.041846153846153845
# [EPISODE 6520] avg score: 0.04233128834355828
# [EPISODE 6540] avg score: 0.04694189602446483
# [EPISODE 6560] avg score: 0.05945121951219512
# [EPISODE 6580] avg score: 0.058662613981762916
# [EPISODE 6600] avg score: 0.05196969696969697
# [EPISODE 6620] avg score: 0.05830815709969789
# [EPISODE 6640] avg score: 0.06310240963855422
# [EPISODE 6660] avg score: 0.10165165165165164
# [EPISODE 6680] avg score: 0.14910179640718563
# [EPISODE 6700] avg score: 0.19746268656716418
# [EPISODE 6720] avg score: 0.17886904761904762
# [EPISODE 6740] avg score: 0.142433234421365
# [EPISODE 6760] avg score: 0.09674556213017751
# [EPISODE 6780] avg score: 0.07551622418879056
# [EPISODE 6800] avg score: 0.08426470588235294
# [EPISODE 6820] avg score: 0.07023460410557185
# [EPISODE 6840] avg score: 0.05160818713450292
# [EPISODE 6860] avg score: 0.04227405247813411
# [EPISODE 6880] avg score: 0.03313953488372093
# [EPISODE 6900] avg score: 0.0336231884057971
# [EPISODE 6920] avg score: 0.033092485549132945
# [EPISODE 6940] avg score: 0.037896253602305474
# [EPISODE 6960] avg score: 0.03692528735632184
# [EPISODE 6980] avg score: 0.036246418338108884
# [EPISODE 7000] avg score: 0.037714285714285714
# [EPISODE 7020] avg score: 0.03304843304843305
# [EPISODE 7040] avg score: 0.033522727272727273
# [EPISODE 7060] avg score: 0.031161473087818695
# [EPISODE 7080] avg score: 0.030649717514124295
# [EPISODE 7100] avg score: 0.029859154929577466
# [EPISODE 7120] avg score: 0.029353932584269663
# [EPISODE 7140] avg score: 0.027450980392156862
# [EPISODE 7160] avg score: 0.026675977653631285
# [EPISODE 7180] avg score: 0.02701949860724234
# [EPISODE 7200] avg score: 0.026805555555555555
# [EPISODE 7220] avg score: 0.027285318559556786
# [EPISODE 7240] avg score: 0.025828729281767954
# [EPISODE 7260] avg score: 0.026584022038567492
# [EPISODE 7280] avg score: 0.026373626373626374
# [EPISODE 7300] avg score: 0.025753424657534246
# [EPISODE 7320] avg score: 0.027049180327868853
# [EPISODE 7340] avg score: 0.026430517711171664
# [EPISODE 7360] avg score: 0.025679347826086957
# [EPISODE 7380] avg score: 0.025609756097560974
# [EPISODE 7400] avg score: 0.026216216216216216
# [EPISODE 7420] avg score: 0.025606469002695417
# [EPISODE 7440] avg score: 0.02486559139784946
# [EPISODE 7460] avg score: 0.025871313672922253
# [EPISODE 7480] avg score: 0.02727272727272727
# [EPISODE 7500] avg score: 0.027866666666666668
# [EPISODE 7520] avg score: 0.026595744680851064
# [EPISODE 7540] avg score: 0.027586206896551724
# [EPISODE 7560] avg score: 0.028306878306878308
# [EPISODE 7580] avg score: 0.027968337730870714
# [EPISODE 7600] avg score: 0.0275
# [EPISODE 7620] avg score: 0.02664041994750656
# [EPISODE 7640] avg score: 0.02617801047120419
# [EPISODE 7660] avg score: 0.025456919060052218
# [EPISODE 7680] avg score: 0.026692708333333332
# [EPISODE 7700] avg score: 0.025714285714285714
# [EPISODE 7720] avg score: 0.027590673575129534
# [EPISODE 7740] avg score: 0.02739018087855297
# [EPISODE 7760] avg score: 0.02654639175257732
# [EPISODE 7780] avg score: 0.02609254498714653
# [EPISODE 7800] avg score: 0.026153846153846153
# [EPISODE 7820] avg score: 0.02608695652173913
# [EPISODE 7840] avg score: 0.026275510204081632
# [EPISODE 7860] avg score: 0.026463104325699746
# [EPISODE 7880] avg score: 0.024746192893401017
# [EPISODE 7900] avg score: 0.024430379746835443
# [EPISODE 7920] avg score: 0.023106060606060606
# [EPISODE 7940] avg score: 0.023173803526448364
# [EPISODE 7960] avg score: 0.023115577889447236
# [EPISODE 7980] avg score: 0.02368421052631579
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/_2/60pd5d4j7n9_65ctcxhm5kv00000gn/T/ipykernel_2175/1907297083.py in <module>
#      21                 break
#      22
# ---> 23         model.train_net()
#      24
#      25     if n_epi%20==0 and n_epi != 0:
#
# /var/folders/_2/60pd5d4j7n9_65ctcxhm5kv00000gn/T/ipykernel_2175/2510407446.py in train_net(self)
#      49
#      50         policy = self.policy(state, softmax_dim=1)
# ---> 51         policy_a = policy.gather(1, action)
#      52         loss = -torch.log(policy_a) * delta.detach() - F.smooth_l1_loss(self.value(state), td_target.detach())
#      53
#
# KeyboardInterrupt:
